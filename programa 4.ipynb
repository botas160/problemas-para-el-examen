# %%
while 1:
  
  print("calculadora ")
  print(" a. Suma")
  print(" b. Resta")
  print(" c. Multiplicacion")
  print(" d. Division ")
  n=str(input("Introduzca una opcion"))

  if n=="a":
    x= float(input("indica el primer valor a sumar "))
    y= float(input("indica el segundo valor a sumar "))
    resultado= x+y
    print(resultado)
  elif n=="b":
    x= float(input("indica el primer valor  "))
    y= float(input("indica el valor que se restara "))
    resultado= x-y
    print(resultado)
  elif n=="c":
    x= float(input("indica el primer valor a multiplicar "))
    y= float(input("indica el valor segundo a valor a multiplicar "))
    resultado= x*y
    print(resultado)
  elif n=="d":
    x= float(input("indica el valor del denominador "))
    y= float(input("indica el valor del divisor "))
    if y==0:
      w= float(input("Introduce un valor distinto a cero "))
      while w==0: 
        w=float(input("introduce un valor distinto a cero "))

      resultado=x/w
      print(resultado)
    else:
      resultado= x/w
      print(resultado)
# Out:
# calculadora
#  a. Suma
#  b. Resta
#  c. Multiplicacion
#  d. Division
# Introduzca una opciona
# indica el primer valor a sumar 2
# indica el segundo valor a sumar 2
# 4.0
# calculadora
#  a. Suma
#  b. Resta
#  c. Multiplicacion
#  d. Division
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ...
