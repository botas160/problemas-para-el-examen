# %%
#Programa 6 

print("Este programa te dice los impuestos que debes por pagar por el salario ganado  ")

s=float(input("Introduce tu salario por mes "))

if s<=10000:
  print(" El porcentaje de impuestos por pagar es el 5%")
  i=s*0.05
  r=s-i
  print("El porcentaje de impuestos por pagar es el 5% ",i)
  print("El salario neto es: ",r)
  print("True")
elif s <=15000:
  print("El porcentaje de impuestos por pagar es el 10%")
  i=s*0.10
  r=s-i
  print("Tu impuesto es de ",i)
  print("El salario neto es: ",r)
  print("True")
elif s<=20000:
  print("El porcentaje de impuestos por pagar es el 15%" )
  i=s*0.15
  r=s-i
  print("El total de impuestos por pagar es ",i)
  print("El salario neto es: ",r)
  print("True")
elif s>=20000:
  print("El porcentaje de impuestos por cobrar es el 18%" )
  i=s*0.18
  r=s-i
  print("El total de impuestos por pagar es ",i)
  print("El salario neto es: ",r)
  print("True")
# Out:
# Este programa te dice los impuestos que debes por pagar por el salario ganado
# Introduce tu salario por mes 11000
# El porcentaje de impuestos por cobrar es el 10%
# Tu impuesto es de  1100.0
# El salario neto es:  9900.0
# True
