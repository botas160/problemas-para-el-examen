# %%
  #programa 5
  
  p=int(input("Cuantos payasos contiene su pedido "))
  m=int(input("Cuantos juegos de mesa contiene su pedido "))
  x=p*150
  y=m*170
  a=10000
  pt=x+y
  if pt>a:
    print("False")
    residuo=pt-a
    print("El excedente de gramos del pedido es: gr
    ",residuo)

  else: 
    print("Gracias por su compra ")
# Out:
# Cuantos payasos contiene su pedido 40
# Cuantos juegos de mesa contiene su pedido 50
# False
# El excedente de gramos del pedido es: gr 4500
