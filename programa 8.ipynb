# %%
# Programa 8

n=(int(input("introduce el numero de renglones del triangulo")))
contador = 0
while contador<n:
  contador = contador + 1
  print('*'*contador)
# Out:
# introduce el numero de renglones del triangulo4
# *
# **
# ***
# ****
