# %%
cadena=input("indica la cadena de caracteres")
numero= int(input("inidca las veces que se imprimira"))
contador=0

while contador<numero:
  contador=contador+1
  print(cadena)
# Out:
# indica la cadena de caractereshola
# inidca las veces que se imprimira3
# hola
# hola
# hola
