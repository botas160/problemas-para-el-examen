# %%
#Programa 10

print("Que deseas calcular el area de un circulo o el volumen de un cilindro")
print("Presiona 1, si es el area del circulo ")
print("presiona 2, si es el volumen de un circulo")
a=int(input("_"))
pi=3.1416

if a==1:
 r=float(input("Introduzca el radio del circulo: "))
 area=pi*r**2
 print(area)

elif a==2:
  r=float(input("Introduzca el radio del circulo: "))
  h=float(input("Introduzca la altura del cilindro: "))
  area=pi*r**2
  volumen=area*h
  print("El volumen del cilindro es:",volumen)
# Out:
# Que deseas calcular el area de un circulo o el volumen de un cilindro
# Presiona 1, si es el area del circulo
# presiona 2, si es el volumen de un circulo
# _2
# Introduzca el radio del circulo: 10
# Introduzca la altura del cilindro: 10
# El volumen del cilindro es: 3141.5999999999995
